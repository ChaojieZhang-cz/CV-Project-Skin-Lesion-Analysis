# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
from torchvision.transforms import ToTensor
import scipy.misc
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import time
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from efficientnet_pytorch import EfficientNet
import pretrainedmodels

seed = 0
np.random.seed(seed)
torch.manual_seed(seed);

# %%
device = torch.device('cuda')

# %%
train_transform = transforms.Compose([])
train_transform.transforms.append(transforms.RandomHorizontalFlip())
train_transform.transforms.append(transforms.RandomVerticalFlip())
transforms.RandomRotation(180, expand=True)
train_transform.transforms.append(transforms.RandomResizedCrop(224, scale=(0.08, 1.0), ratio=(1.0,1.0)))
train_transform.transforms.append(transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0, hue=0))
train_transform.transforms.append(transforms.ToTensor())
train_transform.transforms.append(transforms.Normalize([0.4373, 0.4434, 0.4725],[0.1201, 0.1231, 0.1052]))
train_transform.transforms.append(transforms.RandomErasing())

# %%
test_transform = transforms.Compose([])
test_transform.transforms.append(transforms.RandomResizedCrop(224, scale=(1.0, 1.0), ratio=(1,1)))
test_transform.transforms.append(transforms.ToTensor())
test_transform.transforms.append(transforms.Normalize([0.4373, 0.4434, 0.4725],[0.1201, 0.1231, 0.1052]))

# %%
class image_dataset(Dataset):
    def __init__(self, df_path, train = False):
        self.df = pd.read_csv(df_path)
        self.train = train
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,idx):
        image_name = self.df.iloc[idx]['image']
        image_path = '/scratch/cz2064/myjupyter/Computer Vision/Project/Data/classification/images_preprocessed/'\
        + image_name + '.jpg'
        image = Image.open(image_path)
        
        if self.train:
            image_tensor = train_transform(image)
        else:
            image_tensor = test_transform(image)
            
        metadata = self.df.loc[idx][['sex_index','age_index','anterior torso', 'head/neck', 'lateral torso',\
                                     'lower extremity','oral/genital', 'palms/soles', 'posterior torso',\
                                     'upper extremity']].values.astype('float')
        metadata = torch.tensor(metadata, dtype=torch.float)
        label = self.df.loc[idx][['MEL','NV', 'BCC', 'AK', 'BKL', 'DF', 'VASC', 'SCC','UNK']].values.astype('float')
        label = torch.tensor(label, dtype=torch.float)
        label = label.data.max(-1)[1]
        sample = {'x1': image_tensor, 'x2':metadata,'y': label}
        
        return sample

# %%
train_df_path = '/scratch/cz2064/myjupyter/Computer Vision/Project/Jupyter Notebook/train.csv'
val_df_path = '/scratch/cz2064/myjupyter/Computer Vision/Project/Jupyter Notebook/val.csv'
test_df_path = '/scratch/cz2064/myjupyter/Computer Vision/Project/Jupyter Notebook/test.csv'
BATCH_SIZE = 16
train_loader = DataLoader(image_dataset(train_df_path,train = True), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(image_dataset(val_df_path), batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(image_dataset(test_df_path), batch_size=BATCH_SIZE, shuffle=True)

# %%
image_tensor = next(iter(train_loader))['x1'][0]
inv_normalize = transforms.Normalize(mean=[-0.4373/0.1201, -0.4434/0.1231, -0.4725/0.1052],\
                                     std=[1/0.1201, 1/0.1231, 1/0.1052])
image = inv_normalize(image_tensor)
transforms.ToPILImage()(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2AC0FC09DA20>

# %%
print(pretrainedmodels.model_names)
# Out:
# ['fbresnet152', 'bninception', 'resnext101_32x4d', 'resnext101_64x4d', 'inceptionv4', 'inceptionresnetv2', 'alexnet', 'densenet121', 'densenet169', 'densenet201', 'densenet161', 'resnet18', 'resnet34', 'resnet50', 'resnet101', 'resnet152', 'inceptionv3', 'squeezenet1_0', 'squeezenet1_1', 'vgg11', 'vgg11_bn', 'vgg13', 'vgg13_bn', 'vgg16', 'vgg16_bn', 'vgg19_bn', 'vgg19', 'nasnetamobile', 'nasnetalarge', 'dpn68', 'dpn68b', 'dpn92', 'dpn98', 'dpn131', 'dpn107', 'xception', 'senet154', 'se_resnet50', 'se_resnet101', 'se_resnet152', 'se_resnext50_32x4d', 'se_resnext101_32x4d', 'cafferesnet101', 'pnasnet5large', 'polynet']

# %%
model_name = 'se_resnet152'
se_resnet152 = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained='imagenet')

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.cnn = se_resnet152
      
        self.fc = nn.Linear(1000, 9)
        
    def forward(self, image, data):
        x1 = self.cnn(image)
        #x2 = F.relu(self.fc2(data))
        #x = torch.cat((x1, x2), dim=1)       
        x = self.fc(x1)
        
        return x

# %%
sample = next(iter(train_loader))
image = sample['x1'].to('cpu')
data = sample['x2'].to('cpu')
model = MyModel().to('cpu')
output = model(image,data)

# %%
output.shape
# Out:
# torch.Size([16, 9])

# %%
def train(model, train_loader=train_loader, val_loader=val_loader, learning_rate=5e-5, num_epoch=100):
    start_time = time.time()
    
    distribution = torch.FloatTensor([0.17652477, 0.50707283, 0.13323245, 0.03348905, \
                                  0.10494111, 0.00894796, 0.00986907, 0.02592276, 0.]).to(device)
    loss_fn = nn.CrossEntropyLoss(weight=distribution)
    optimizer = optim.Adam(model.parameters(),lr=learning_rate)
    
    train_loss_return = []
    train_acc_return = []
    val_loss_return = []
    val_acc_return = []
    best_acc = 0
    
    for epoch in range(num_epoch):
        # Training steps
        correct = 0
        total = 0
        predictions = []
        truths = []
        model.train()
        train_loss_list = []
        for i, (sample) in enumerate(train_loader):
            image = sample['x1'].to(device)
            data = sample['x2'].to(device)
            labels = sample['y'].to(device)
            outputs = model(image,data)
            pred = outputs.data.max(-1)[1]
            predictions += list(pred.cpu().numpy())
            truths += list(labels.cpu().numpy())
            total += labels.size(0)
            correct += (pred == labels).sum()
            model.zero_grad()
            loss = loss_fn(outputs, labels)
            train_loss_list.append(loss.item())
            loss.backward()
            optimizer.step()
        # report performance
        acc = (100 * correct / total)
        train_acc_return.append(acc)
        train_loss_every_epoch = np.average(train_loss_list)
        train_loss_return.append(train_loss_every_epoch)
        print('----------Epoch{:2d}/{:2d}----------'.format(epoch+1,num_epoch))
        print('Train set | Loss: {:6.4f} | Accuracy: {:4.2f}% '.format(train_loss_every_epoch, acc))
        
        # Evaluate after every epochh
        correct = 0
        total = 0
        model.eval()
        predictions = []
        truths = []
        val_loss_list = []
        with torch.no_grad():
            for i, (sample) in enumerate(val_loader):
                image = sample['x1'].to(device)
                data = sample['x2'].to(device)
                labels = sample['y'].to(device)
                outputs = model(image,data)
                loss = loss_fn(outputs, labels)
                val_loss_list.append(loss.item())
                pred = outputs.data.max(-1)[1]
                predictions += list(pred.cpu().numpy())
                truths += list(labels.cpu().numpy())
                total += labels.size(0)
                correct += (pred == labels).sum()
            # report performance
            acc = (100 * correct / total)
            val_acc_return.append(acc)
            val_loss_every_epoch = np.average(val_loss_list)
            val_loss_return.append(val_loss_every_epoch)
            if acc > best_acc:
                best_acc = acc
                best_model_wts = model.state_dict()
            save_model(model,train_loss_return,train_acc_return,val_loss_return,val_acc_return,best_model_wts)
            elapse = time.strftime('%H:%M:%S', time.gmtime(int((time.time() - start_time))))
            print('Test set | Loss: {:6.4f} | Accuracy: {:4.2f}% | time elapse: {:>9}'\
                  .format(val_loss_every_epoch, acc,elapse))
    return model,train_loss_return,train_acc_return,val_loss_return,val_acc_return,best_model_wts

def save_model(model,train_loss_return,train_acc_return,val_loss_return,val_acc_return,best_model_wts):
    state = {'best_model_wts':best_model_wts, 'model':model, \
             'train_loss':train_loss_return, 'train_acc':train_acc_return,\
             'val_loss':val_loss_return, 'val_acc':val_acc_return}
    torch.save(state, 'checkpoint_Model_seresnet152.pt')
    return None

# %%
model = MyModel().to(device)

# %%
train(model)
# Out:
# tensor(2.4112, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.9611, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.6626, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.4606, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.1329, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0346, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0666, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7894, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.1557, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5998, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.4891, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6966, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8931, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.4087, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4992, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9560, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4715, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6949, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6205, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3975, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0325, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0107, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9683, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4123, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6166, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9593, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9924, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4266, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.3826, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5015, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4303, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.2463, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6242, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5467, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8301, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4496, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5117, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4737, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5099, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5938, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6447, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4754, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4615, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6092, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6263, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7073, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8072, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3571, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8593, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5680, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6017, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4242, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6630, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4635, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8016, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0753, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5655, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8234, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6453, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6966, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6249, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4681, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7716, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7145, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6149, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5813, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5346, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6059, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4896, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5725, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3855, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6649, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6079, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5923, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3000, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6962, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3465, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5230, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5673, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5398, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6807, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8025, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5447, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4120, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7703, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4322, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3776, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5146, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4443, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9091, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5682, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4611, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8236, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4068, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4890, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3669, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3030, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6908, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6804, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6062, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.1943, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3881, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3600, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3392, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5915, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9187, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4017, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4960, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8465, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7487, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6754, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4572, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5099, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4825, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5319, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5365, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9080, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7571, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4975, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4266, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6251, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7884, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7405, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4695, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4366, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5638, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5673, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5617, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6435, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3261, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3927, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4792, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4174, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8391, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4631, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2624, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4162, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3666, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2614, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4564, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3556, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.1885, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5034, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6053, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6786, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5413, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.1983, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5767, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4760, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2406, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4705, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2738, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3920, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2738, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0863, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4834, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2186, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3909, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4748, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8395, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6747, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2397, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3674, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4911, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7274, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8408, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5324, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4897, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8349, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3465, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4519, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5741, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4455, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5437, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2658, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4350, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2969, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3662, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9519, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8701, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5126, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7958, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4448, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4179, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7679, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7507, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8483, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5326, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4440, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.9754, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5763, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7177, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3912, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4701, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7282, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6321, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5039, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7772, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6138, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5027, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8225, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4814, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7602, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5563, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4653, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3592, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5388, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4209, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7029, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4155, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6189, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6005, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4414, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.0325, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4032, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8486, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4506, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6802, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8623, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3797, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4270, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4479, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6398, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3886, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7882, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3708, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.1512, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2980, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5528, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6411, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3526, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4952, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5204, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6821, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7020, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.7051, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.2755, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6112, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5994, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4147, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4513, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3045, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3698, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6792, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.1720, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5667, device='cuda:0', grad_fn=<NllLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-9d3046b5d0d4> in <module>
# ----> 1 train(model)
#
# <ipython-input-74-e7ca0d5a38fb> in train(model, train_loader, val_loader, learning_rate, num_epoch)
#      21         model.train()
#      22         train_loss_list = []
# ---> 23         for i, (sample) in enumerate(train_loader):
#      24             image = sample['x1'].to(device)
#      25             data = sample['x2'].to(device)
#
# /scratch/cz2064/envs/dl4med/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /scratch/cz2064/envs/dl4med/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /scratch/cz2064/envs/dl4med/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /scratch/cz2064/envs/dl4med/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-66-f5450e99aa39> in __getitem__(self, idx)
#      11         image_path = '/scratch/cz2064/myjupyter/Computer Vision/Project/Data/classification/images_preprocessed/'\
#      12         + image_name + '.jpg'
# ---> 13         image = Image.open(image_path)
#      14
#      15         if self.train:
#
# /scratch/cz2064/envs/dl4med/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2816         exclusive_fp = True
#    2817
# -> 2818     prefix = fp.read(16)
#    2819
#    2820     preinit()
#
# KeyboardInterrupt:
